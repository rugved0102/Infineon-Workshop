# %% [markdown]
# # Tabluar data pre-processong

# %% [markdown]
# # import all required libraries

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import random

# Set seed for reproducibility
np.random.seed(42)
random.seed(42)

# %% [markdown]
# # load data set

# %%
df=pd.read_csv('sample_data.csv')

# %%
df.head(100)
# Out:
#     Temperature  Humidity Condition        Date  WindSpeed  CityCode
# 0     19.966733      76.0    Cloudy  01/14/2025      23.91      1782
# 1     13.404275      54.0     Rainy  13-01-2025      31.72      1009
# 2     24.022196      38.0     Rainy  01/12/2025      26.20      1983
# 3     19.213931      33.0    Cloudy  11-01-2025      39.69      1377
# 4     25.402299      43.0    Cloudy  01/10/2025      11.35      1632
# ..          ...       ...       ...         ...        ...       ...
# 95    16.007805      61.0     Sunny  11-10-2024       9.77      1998
# 96    26.706560      72.0     Sunny  10/10/2024      33.24      1707
# 97    15.581111      82.0     Sunny  09-10-2024      34.58      1780
# 98    22.869835      59.0     Sunny  10/08/2024      30.74      1560
# 99    11.232131      68.0     Rainy  07-10-2024       4.52      1827
#
# [100 rows x 6 columns]

# %%
# checck dataframe description

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  200 non-null    float64
#  1   Humidity     194 non-null    float64
#  2   Condition    191 non-null    object
#  3   Date         200 non-null    object
#  4   WindSpeed    195 non-null    float64
#  5   CityCode     200 non-null    int64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 9.5+ KB

# %%
#check null values

df.isna().sum()
# Out:
# Temperature    0
# Humidity       6
# Condition      9
# Date           0
# WindSpeed      5
# CityCode       0
# dtype: int64

# %%
# Handle missing values

df['Humidity'].fillna(df['Humidity'].mean(), inplace=True)
df['WindSpeed'].fillna(df['WindSpeed'].mean(), inplace=True)
df['Condition'].fillna('Unknown', inplace=True)

# %%
df.isna().sum()
# Out:
# Temperature    0
# Humidity       0
# Condition      0
# Date           0
# WindSpeed      0
# CityCode       0
# dtype: int64

# %% [markdown]
# # Changing Data Types

# %% [markdown]
# # checking irregularity in date

# %%
df['Date'].unique()
# Out:
# array(['01/14/2025', '13-01-2025', '01/12/2025', '11-01-2025',
#        '01/10/2025', '09-01-2025', '01/08/2025', '07-01-2025',
#        '01/06/2025', '05-01-2025', '01/04/2025', '03-01-2025',
#        '01/02/2025', '01-01-2025', '12/31/2024', '30-12-2024',
#        '12/29/2024', '28-12-2024', '12/27/2024', '26-12-2024',
#        '12/25/2024', '24-12-2024', '12/23/2024', '22-12-2024',
#        '12/21/2024', '20-12-2024', '12/19/2024', '18-12-2024',
#        '12/17/2024', '16-12-2024', '12/15/2024', '14-12-2024',
#        '12/13/2024', '12-12-2024', '12/11/2024', '10-12-2024',
#        '12/09/2024', '08-12-2024', '12/07/2024', '06-12-2024',
#        '12/05/2024', '04-12-2024', '12/03/2024', '02-12-2024',
#        '12/01/2024', '30-11-2024', '11/29/2024', '28-11-2024',
#        '11/27/2024', '26-11-2024', '11/25/2024', '24-11-2024',
#        '11/23/2024', '22-11-2024', '11/21/2024', '20-11-2024',
#        '11/19/2024', '18-11-2024', '11/17/2024', '16-11-2024',
#        '11/15/2024', '14-11-2024', '11/13/2024', '12-11-2024',
#        '11/11/2024', '10-11-2024', '11/09/2024', '08-11-2024',
#        '11/07/2024', '06-11-2024', '11/05/2024', '04-11-2024',
#        '11/03/2024', '02-11-2024', '11/01/2024', '31-10-2024',
#        '10/30/2024', '29-10-2024', '10/28/2024', '27-10-2024',
#        '10/26/2024', '25-10-2024', '10/24/2024', '23-10-2024',
#        '10/22/2024', '21-10-2024', '10/20/2024', '19-10-2024',
#        '10/18/2024', '17-10-2024', '10/16/2024', '15-10-2024',
#        '10/14/2024', '13-10-2024', '10/12/2024', '11-10-2024',
#        '10/10/2024', '09-10-2024', '10/08/2024', '07-10-2024',
#        '10/06/2024', '05-10-2024', '10/04/2024', '03-10-2024',
#        '10/02/2024', '01-10-2024', '09/30/2024', '29-09-2024',
#        '09/28/2024', '27-09-2024', '09/26/2024', '25-09-2024',
#        '09/24/2024', '23-09-2024', '09/22/2024', '21-09-2024',
#        '09/20/2024', '19-09-2024', '09/18/2024', '17-09-2024',
#        '09/16/2024', '15-09-2024', '09/14/2024', '13-09-2024',
#        '09/12/2024', '11-09-2024', '09/10/2024', '09-09-2024',
#        '09/08/2024', '07-09-2024', '09/06/2024', '05-09-2024',
#        '09/04/2024', '03-09-2024', '09/02/2024', '01-09-2024',
#        '08/31/2024', '30-08-2024', '08/29/2024', '28-08-2024',
#        '08/27/2024', '26-08-2024', '08/25/2024', '24-08-2024',
#        '08/23/2024', '22-08-2024', '08/21/2024', '20-08-2024',
#        '08/19/2024', '18-08-2024', '08/17/2024', '16-08-2024',
#        '08/15/2024', '14-08-2024', '08/13/2024', '12-08-2024',
#        '08/11/2024', '10-08-2024', '08/09/2024', '08-08-2024',
#        '08/07/2024', '06-08-2024', '08/05/2024', '04-08-2024',
#        '08/03/2024', '02-08-2024', '08/01/2024', '31-07-2024',
#        '07/30/2024', '29-07-2024', '07/28/2024', '27-07-2024',
#        '07/26/2024', '25-07-2024', '07/24/2024', '23-07-2024',
#        '07/22/2024', '21-07-2024', '07/20/2024', '19-07-2024',
#        '07/18/2024', '17-07-2024', '07/16/2024', '15-07-2024',
#        '07/14/2024', '13-07-2024', '07/12/2024', '11-07-2024',
#        '07/10/2024', '09-07-2024', '07/08/2024', '07-07-2024',
#        '07/06/2024', '05-07-2024', '07/04/2024', '03-07-2024',
#        '07/02/2024', '01-07-2024', '06/30/2024', '29-06-2024'],
#       dtype=object)

# %%
# Function to parse date strings in different formats
def parse_date(date_str):
    for fmt in ('%m/%d/%Y', '%d-%m-%Y'):
        try:
            return datetime.strptime(date_str, fmt)
        except ValueError:
            pass
    raise ValueError(f"No valid date format found for {date_str}")

# Applying the function to convert date strings to datetime
df['Date'] = df['Date'].apply(parse_date)

# Change the CityCode column from string to integer type
df['CityCode'] = df['CityCode'].astype(int)

# Display updated data types and information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  200 non-null    float64
#  1   Humidity     200 non-null    float64
#  2   Condition    200 non-null    object
#  3   Date         200 non-null    datetime64[ns]
#  4   WindSpeed    200 non-null    float64
#  5   CityCode     200 non-null    int32
# dtypes: datetime64[ns](1), float64(3), int32(1), object(1)
# memory usage: 8.7+ KB

# %%
df.head(10)
# Out:
#    Temperature  Humidity Condition       Date  WindSpeed  CityCode
# 0    19.966733      76.0    Cloudy 2025-01-14      23.91      1782
# 1    13.404275      54.0     Rainy 2025-01-13      31.72      1009
# 2    24.022196      38.0     Rainy 2025-01-12      26.20      1983
# 3    19.213931      33.0    Cloudy 2025-01-11      39.69      1377
# 4    25.402299      43.0    Cloudy 2025-01-10      11.35      1632
# 5    10.775474      66.0    Cloudy 2025-01-09      14.37      1636
# 6    14.914039      63.0     Sunny 2025-01-08      15.35      1681
# 7    22.583347      40.0     Rainy 2025-01-07      18.63      1583
# 8    16.004447      70.0     Sunny 2025-01-06      33.44      1151
# 9    19.177322      85.0     Sunny 2025-01-05       9.43      1719

# %%
# Summary statistics
df.describe()
# Out:
#        Temperature    Humidity   WindSpeed     CityCode
# count   200.000000  200.000000  200.000000   200.000000
# mean     19.373721   58.675258   20.191128  1526.425000
# std       5.133649   16.227426   10.838986   272.212661
# min       6.703243   30.000000    0.100000  1009.000000
# 25%      15.906874   44.000000   11.745000  1298.750000
# 50%      19.387027   58.675258   20.885000  1553.000000
# 75%      22.955097   70.000000   28.320000  1740.500000
# max      32.849634   89.000000   39.730000  1998.000000
